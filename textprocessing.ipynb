# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashika-06/Yashika-06/blob/main/textprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tf = open('textfile.txt')
text = tf.read()
print(text)
# Out:
# nervous system has two principal cells: neurons and glial cells which are ensembled into ensembles called neural circuits which process specific types of information.
# *sensory sys: represent info about one's state

# %%
import nltk
nltk.download("popular")
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# ...

# %%
from nltk.tokenize import sent_tokenize
st = sent_tokenize(text.lower())
print(st)
# Out:
# ['nervous system has two principal cells: neurons and glial cells which are ensembled into ensembles called neural circuits which process specific types of information.', "*sensory sys: represent info about one's state"]

# %%
from wordcloud import WordCloud

# %%
import matplotlib.pyplot as plt

# %%
tf = open('textfile.txt')
text = tf.read()
wordcloud = WordCloud(width=800,height=800,background_color='WHITE').generate(text)
plt.figure(figsize=(10,8))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from nltk.tokenize import word_tokenize
wt = word_tokenize(text.lower())
print(wt)
# Out:
# ['nervous', 'system', 'has', 'two', 'principal', 'cells', ':', 'neurons', 'and', 'glial', 'cells', 'which', 'are', 'ensembled', 'into', 'ensembles', 'called', 'neural', 'circuits', 'which', 'process', 'specific', 'types', 'of', 'information', '.', '*', 'sensory', 'sys', ':', 'represent', 'info', 'about', 'one', "'s", 'state']

# %%
from nltk.probability import FreqDist
fdist = FreqDist(wt)
fdist.most_common(3)
# Out:
# [('cells', 2), (':', 2), ('which', 2)]

# %%
from string import punctuation
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
"nlp"=="nlp."
# Out:
# False

# %%
tc = "".join([char for char in text if char not in punctuation])
print(tc)
# Out:
# nervous system has two principal cells neurons and glial cells which are ensembled into ensembles called neural circuits which process specific types of information
# sensory sys represent info about ones state

# %%
from nltk.corpus import stopwords
stopwords = stopwords.words("english")
#print(stopwords)
nostop = [word for word in wt if word not in stopwords]
print(nostop)
# Out:
# ['nervous', 'system', 'two', 'principal', 'cells', ':', 'neurons', 'glial', 'cells', 'ensembled', 'ensembles', 'called', 'neural', 'circuits', 'process', 'specific', 'types', 'information', '.', '*', 'sensory', 'sys', ':', 'represent', 'info', 'one', "'s", 'state']

# %%
def clean_text(text):
     text = "".join([char for char in text if char not in punctuation])
     tokens = word_tokenize(text.lower())
     print(tokens)
     nostop = [char for char in tokens if char not in stopwords]
     return

#print(clean_text(text))
print(clean_text("Thapar Institute, is a private deemed-university founded in 1956 by Karam Chand Thapar."))
# Out:
# ['thapar', 'institute', 'is', 'a', 'private', 'deemeduniversity', 'founded', 'in', '1956', 'by', 'karam', 'chand', 'thapar']
# None
